# %%
# %matplotlib inline

from algos import perf
from algos.perf import perf_bin_search

# %%
p = perf_bin_search.PerfBinSearchFound()
perf.draw_line_chart(p, [10 ** i for i in range(1, 8)])

# %%
np = perf_bin_search.PerfBinSearchNotFound()
perf.draw_line_chart(np, [10 ** i for i in range(1, 8)])
